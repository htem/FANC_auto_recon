# %%
import sys
sys.path.append('/Users/brandon/Documents/Repositories/Python/')

# %%
from FANC_auto_recon.annotations import schema_download
from FANC_auto_recon.neuroglancer_utilities import get_client,get_cv_path
import numpy as np
from cloudvolume import CloudVolume

# %%
client,token = get_client()

# %%
table_name = ['contra-contraltm-4-5']

for i in table_name:
    annot_table = schema_download.download_annotation_table(client,i)
    syn_table = schema_download.generate_synapse_table(annot_table)
    syn_table.to_csv('/Users/brandon/Desktop/synapse tables/' + i + '.csv')

# %%
client.annotation.get_annotation('contra_contraltm-4-5',annotation_ids=range(10000))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-17-92aba50aba27> in <module>
# ----> 1 client.annotation.get_annotation('contra_contraltm-4-5',annotation_ids=range(10000))
#
# ~/anaconda3/envs/connectomics_analysis/lib/python3.7/site-packages/annotationframeworkclient/annotationengine.py in get_annotation(self, table_name, annotation_ids, aligned_volume_name)
#     414         }
#     415         response = self.session.get(url, params=params)
# --> 416         return handle_response(response)
#     417
#     418     def post_annotation(self, table_name, data, aligned_volume_name=None):
#
# ~/anaconda3/envs/connectomics_analysis/lib/python3.7/site-packages/annotationframeworkclient/base.py in handle_response(response, as_json)
#       9 def handle_response(response, as_json=True):
# ...

# %%
cv = CloudVolume('graphene://https://wclee.api.zetta.ai/segmentation/table/vnc1_full_v3align_2',use_https=True)

# %%
cv.
# Out:
# {'data_dir': 'gs://zetta_lee_fly_vnc_001_segmentation/vnc1_full_v3align_2/realigned_v1/ws/full_run_v1',
#  'graph': {'chunk_size': [1024, 512, 128],
#   'bounding_box': [1024, 512, 128],
#   'n_bits_for_layer_id': 8,
#   'cv_mip': 0,
#   'n_layers': 9,
#   'spatial_bit_masks': {'9': 1,
#    '8': 1,
#    '7': 2,
#    '6': 3,
#    '5': 4,
#    '4': 5,
#    '3': 6,
#    '2': 10,
#    '1': 10}},
#  'data_type': 'uint64',
#  'mesh': 'graphene_meshes',
#  'mesh_metadata': {'uniform_draco_grid_size': 18,
#   'unsharded_mesh_dir': 'dynamic'},
#  'num_channels': 1,
#  'scales': [{'chunk_sizes': [[256, 256, 32]],
#    'compressed_segmentation_block_size': [8, 8, 8],
#    'encoding': 'compressed_segmentation',
#    'key': '17.2_17.2_45.0',
#    'resolution': [17.2, 17.2, 45.0],
#    'size': [20992, 56064, 4363],
#    'voxel_offset': [256, 256, 32]},
#   {'chunk_sizes': [[256, 256, 32]],
#    'compressed_segmentation_block_size': [8, 8, 8],
#    'encoding': 'compressed_segmentation',
# ...

# %%
client.chunkedgraph.get_change_log()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-46b7f0eae892> in <module>
# ----> 1 client.chunkedgraph.get_change_log()
#
# TypeError: get_change_log() missing 1 required positional argument: 'root_id'
